# %% [markdown]
# # 第十章: 利用K-means聚类算法对未标注数据分组

# %% [markdown]
# # 10.1 K-means聚类算法

# %%
import kMeans
from numpy import *

# %%
datMat = mat(kMeans.loadDataSet('testSet.txt'))

# %%
myCentroids, clustAssing = kMeans.kMeans(datMat, 4)
# Out:
# [[ 2.17400685  4.52519674]
#  [ 0.56584805 -3.50853378]
#  [-5.14465245  1.02048436]
#  [ 1.9626017  -1.77866886]]
# [[ 1.88660209  3.23434291]
#  [-1.955139   -3.29307143]
#  [-3.25237192  0.76234932]
#  [ 3.1666855  -2.38897356]]
# [[ 2.27289195  3.17080855]
#  [-3.19984738 -2.96423548]
#  [-2.59466044  2.67574033]
#  [ 2.926737   -2.70147753]]
# [[ 2.6265299   3.10868015]
#  [-3.38237045 -2.9473363 ]
#  [-2.46154315  2.78737555]
#  [ 2.80293085 -2.7315146 ]]

# %% [markdown]
# # 使用后处理来提高聚类性能

# %%
datMat3 = mat(kMeans.loadDataSet('testSet2.txt'))

# %%
centList, myNewAssment = kMeans.biKmeans(datMat3, 3)
# Out:
# [[-3.28669541  4.23588488]
#  [-0.06510603  0.51791132]]
# [[-3.06779095  3.33769884]
#  [ 1.19084544  0.24642754]]
# [[-2.94737575  3.3263781 ]
#  [ 1.23710375  0.17480612]]
# sseSplit, and notSplit:  570.722757425 0.0
# the bestCentToSplit is:  0
# the len of bestClustAss is:  60
# [[-3.44013824  3.13311834]
#  [-0.6898684   2.61402149]]
# [[-3.20990224  3.40433812]
#  [-1.45972567  2.88460467]]
# [[-3.58362738  3.28784469]
#  [-1.76576557  3.39794014]]
# sseSplit, and notSplit:  22.9717718963 532.659806789
# [[-0.79566993  4.72041207]
#  [ 0.89687687 -0.47952749]]
# [[ 2.65268742  3.70569817]
#  [ 0.63042504 -1.33843332]]
# [[ 2.95977168  3.26903847]
#  [-0.32150057 -2.62473743]]
# [[ 2.93386365  3.12782785]
#  [-0.45965615 -2.7782156 ]]
# sseSplit, and notSplit:  68.6865481262 38.0629506357
# the bestCentToSplit is:  1
# the len of bestClustAss is:  40

# %%
centList
# Out:
# matrix([[-2.94737575,  3.3263781 ],
#         [ 2.93386365,  3.12782785],
#         [-0.45965615, -2.7782156 ]])

# %% [markdown]
# # 示例： 对地图上的点进行聚类

# %%
kMeans.clusterClubs(4)
# Out:
# [[-122.69400065   45.51595439]
#  [-122.76624147   45.48936604]]
# [[-122.6045191    45.51787591]
#  [-122.77486818   45.48294173]]
# [[-122.60075121   45.5183743 ]
#  [-122.76489154   45.48616931]]
# [[-122.59600522   45.51553426]
#  [-122.76009173   45.50068747]]
# sseSplit, and notSplit:  3339.55439328 0.0
# the bestCentToSplit is:  0
# the len of bestClustAss is:  69
# [[-122.54540846   45.47258335]
#  [-122.55782857   45.53926812]]
# [[-122.57056181   45.48078662]
#  [-122.61219648   45.53764639]]
# [[-122.552436     45.49026452]
#  [-122.6335649    45.53731852]]
# [[-122.54365339   45.49160343]
#  [-122.6348469    45.53328939]]
# [[-122.53228195   45.49259215]
#  [-122.6334895    45.52902962]]
# sseSplit, and notSplit:  1386.02403319 963.762871674
# [[-122.806427     45.51962763]
#  [-122.7539843    45.62106122]]
# [[-122.75838933   45.47278083]
#  [-122.76690133   45.612314  ]]
# sseSplit, and notSplit:  384.896055 2375.79152161
# the bestCentToSplit is:  0
# the len of bestClustAss is:  54
# [[-122.39242901   45.45932236]
#  [-122.56622445   45.49425054]]
# [[-122.4009285    45.46897   ]
#  [-122.54687678   45.49521683]]
# sseSplit, and notSplit:  450.8723663 1650.42451583
# [[-122.76372999   45.58537345]
#  [-122.74380205   45.40337839]]
# [[-122.76627263   45.546612  ]
#  [-122.75302786   45.44820229]]
# [[-122.76158867   45.56439133]
#  [-122.75909378   45.45821822]]
# [[-122.755383     45.5949895 ]
#  [-122.761804     45.46639582]]
# sseSplit, and notSplit:  363.203345241 1386.02403319
# [[-122.60866588   45.49328134]
#  [-122.59086914   45.46546201]]
# [[-122.63332718   45.53105558]
#  [-122.638846     45.462173  ]]
# [[-122.63281863   45.53599117]
#  [-122.638521     45.476818  ]]
# [[-122.63295532   45.54360168]
#  [-122.63497333   45.48855167]]
# [[-122.63201483   45.54490925]
#  [-122.6370287    45.4909185 ]]
# [[-122.63095604   45.54611291]
#  [-122.63878673   45.49331   ]]
# [[-122.62439945   45.549932  ]
#  [-122.64647529   45.49916907]]
# [[-122.61308487   45.55653638]
#  [-122.65162694   45.50457917]]
# [[-122.60946453   45.5579654 ]
#  [-122.65245658   45.50618558]]
# sseSplit, and notSplit:  314.726441107 1663.12526071
# the bestCentToSplit is:  1
# the len of bestClustAss is:  15
